# %%
# codinig:utf-8

import urllib.request
import pandas as pd

# %%
def downpic(jpg_link,path):
    print( 'ending',jpg_link)
    urllib.request.urlretrieve(jpg_link, path)

# %%
pd_df = pd.read_excel('H:/360MoveData/Users/zhh/Desktop/天猫-牛仔-0429.xlsx')
pd_df.head()
# Out:
#     品牌          宝贝编号                               宝贝名称     价格   销售量    累计销量  \
# 0  a21  579126304648   A21男装春夏季纯棉男裤牛仔裤男薄款小脚潮流 男生小直筒男款裤子  119.0  9821   37363
# 1  a21  555337765523      A21男修身牛仔裤潮流夏季弹力男士小脚裤休闲裤子男小脚长裤  139.0  4806  104103
# 2  a21  572319301147     A21新款春季男生牛仔裤男修身小脚潮流弹力春秋款男士裤子潮牌  169.0   235   26437
# 3  a21  572711994246        A21九分裤男修身秋季低腰弹力水洗学生简约男士牛仔裤潮  159.0   318   12259
# 4  a21  584860094859  A21春季2019新款男装 休闲百搭潮感舒适翻领全棉牛仔长袖衬衫男  169.0   203    1752
#
#    页数                                           宝贝链接  \
# 0   1  //detail.m.tmall.com/item.htm?id=579126304648
# 1   1  //detail.m.tmall.com/item.htm?id=555337765523
# 2   1  //detail.m.tmall.com/item.htm?id=572319301147
# 3   1  //detail.m.tmall.com/item.htm?id=572711994246
# 4   2  //detail.m.tmall.com/item.htm?id=584860094859
#
#                                                 图片链接   性别
# 0  //img.alicdn.com/bao/uploaded/i4/1601145275/O1...  boy
# 1  //img.alicdn.com/bao/uploaded/i3/1601145275/O1...  boy
# ...

# %%
url_pic = ['http:'+ _ for _ in pd_df['图片链接'].tolist()]
url_path =['H:/360MoveData/Users/zhh/Desktop/牛仔/pic/'+str(_)+'.jpg' for _ in pd_df['宝贝编号'].tolist()]
# https://img.alicdn.com/bao/uploaded/i3/1601145275/O1CN011opziEbmvBLFJv4_!!0-item_pic.jpg
# urllib.urllib.urlj

# %%
[downpic(url_pic[i],url_path[i]) for i in range(len(url_pic)) if i>=0]
# Out:
# ending http://img.alicdn.com/bao/uploaded/i4/1601145275/O1CN01VasoKY1opzlbD1Hs9_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i3/1601145275/O1CN011opziEbmvBLFJv4_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i3/1601145275/O1CN01PFaDYY1opzjcyTbrv_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i2/1601145275/O1CN016C1B1V1opzkm1lF2Y_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i2/1601145275/O1CN01TexaSw1opzkEgPZKO_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i2/1601145275/O1CN01VftBk91opzksBM9mr_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i1/1601145275/O1CN011opzicf639CrNEn_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i1/1601145275/O1CN01ve39KX1opzkQFLLlA_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i4/1601145275/O1CN01ROk9v71opzjOqI6bS_!!0-item_pic.jpg
# ending http://img.alicdn.com/bao/uploaded/i3/1601145275/O1CN01Vv4L831opzkWth6pS_!!0-item_pic.jpg
# ...
